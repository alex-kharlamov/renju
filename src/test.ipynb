# %%
from renju import Game, run_test, Player, PyPlotUI
from agent import BackendAgent, HumanAgent

# %matplotlib notebook

# %%
run_test(BackendAgent('python3 ham_agent.py', 'B'), BackendAgent('python3 ham_agent.py', 'W'))
# Out:
# <img src="data:image/png;base64,..." width="800">
#   File "/home/axcel/Documents/renju/src/renju.py", line 194, in run_test
#     for game, probs in loop(game, black, white, timeout):
#   File "/home/axcel/Documents/renju/src/renju.py", line 182, in loop
#     probs = future.result(timeout=timeout)
#   File "/usr/lib/python3.5/concurrent/futures/_base.py", line 400, in result
#     self._condition.wait(timeout)
#   File "/usr/lib/python3.5/threading.py", line 293, in wait
#     waiter.acquire()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/axcel/Documents/renju/src/renju.py in run_test(black, white, timeout)
#     193     try:
# --> 194         for game, probs in loop(game, black, white, timeout):
#     195             ui.update(game, probs)
#
# /home/axcel/Documents/renju/src/renju.py in loop(game, black, white, timeout)
#     181             future = executor.submit(lambda game: agent.policy(game), game)
# --> 182             probs = future.result(timeout=timeout)
#     183
#
# /usr/lib/python3.5/concurrent/futures/_base.py in result(self, timeout)
#     399
# --> 400             self._condition.wait(timeout)
#     401
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-114257d63bbb> in <module>()
# ----> 1 run_test(BackendAgent('python3 ham_agent.py', 'B'), BackendAgent('python3 ham_agent.py', 'W'))
#
# /home/axcel/Documents/renju/src/renju.py in run_test(black, white, timeout)
#     199         print(e)
#     200         traceback.print_tb(tb)
# --> 201         return game.player().another()
#     202
#     203     return game.result()
#
# TypeError: player() takes 0 positional arguments but 1 was given
